# %% [raw]
# !pip install yfinance pandas matplotlib beautifulsoup4

# %% [markdown]
# ### Question 1: Use the yfinance to Extract Stock Data
#
# Using the `Ticker` function, enter the ticker symbol of the stock we want to extract data on to create a ticker object. The stock is Tesla and its ticker symbol is `TSLA`.

# %% [markdown]
# Using the ticker object and the function `history`, extract stock information and save it in a dataframe named `tesla_stock`. Set the `period` parameter to `max` so we get information for the maximum amount of time.

# %% [markdown]
# Reset the index, save, and display the first five rows of the `tesla_stock` dataframe using the `head` function. Take a screenshot of the results.

# %%
import yfinance as yf

# Descargar datos de Tesla
tesla_data = yf.Ticker("TSLA")
tesla_stock = tesla_data.history(period="max")

# Restablecer el índice y mostrar las primeras filas
tesla_stock.reset_index(inplace=True)
tesla_stock.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %% [markdown]
# ### Question 2: Extract Tesla Revenue Data Using Web Scraping
#
# Extract Tesla's revenue data using web scraping. Navigate to the Tesla financials page and scrape the revenue table. Save the results in a pandas DataFrame named `tesla_revenue`.
#
# Display the first five rows of the `tesla_revenue` dataframe using the `head` function.

# %%
         Date  Revenue
41  2010-09-30       31
42  2010-06-30       28
43  2010-03-31       21
45  2009-09-30       46
46  2009-06-30       27

# %%
# Importar las bibliotecas necesarias
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar los datos históricos de Tesla
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")
tesla_data.reset_index(inplace=True)

# Función para graficar
def make_graph(data, title, color):
    plt.figure(figsize=(6, 4))  # Tamaño reducido
    plt.plot(data['Date'], data['Close'], label=f'Close Price ({color})', color=color)
    plt.xlabel('Date')
    plt.ylabel('Close Price (USD)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# Graficar Tesla en azul y rojo
make_graph(tesla_data, "Tesla Stock Price (Blue)", color='blue')
make_graph(tesla_data, "Tesla Stock Price (Red)", color='red')

# %%
# Importar las bibliotecas necesarias
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar los datos históricos de GameStop
gamestop = yf.Ticker("GME")
gamestop_data = gamestop.history(period="max")
gamestop_data.reset_index(inplace=True)

# Función para graficar
def make_graph(data, title, color):
    plt.figure(figsize=(6, 4))  # Tamaño reducido
    plt.plot(data['Date'], data['Close'], label=f'Close Price ({color})', color=color)
    plt.xlabel('Date')
    plt.ylabel('Close Price (USD)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# Graficar GameStop en azul y rojo
make_graph(gamestop_data, "GameStop Stock Price (Blue)", color='blue')
make_graph(gamestop_data, "GameStop Stock Price (Red)", color='red')
